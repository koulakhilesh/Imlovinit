# %%
from scripts.lovinit import imlovint
from data.db_description import getDatabase

# %%
chainDB=getDatabase()
print([item['Name'] for item in chainDB])
# Out:
# ['MASTER_PLAN', 'MCD', 'LIBRARY', 'MUSEUMS', 'E_WASTE']

# %%
imlovint_class=imlovint(chain='E_WASTE',notebook=True)
#imlovint_class.getBoundary(plot=True)
#imlovint_class.justDots()
imlovint_class.drawVoronoi()

# %%
nearbyDF=imlovint_class.getNearby(address='Bukit Timah' , distance=0.03)
# Out:
# Found 10 results, using the first default one
# 20 TOH YI DRIVE BUKIT TIMAH COMMUNITY CLUB SINGAPORE 596569
#
# 33 chain Found

# %%
nearbyDF.head()
# Out:
#                                                 Name  \
# 0  NEA Producer Responsibility Scheme - ALBA E-wa...
# 1  NEA Producer Responsibility Scheme - ALBA E-wa...
# 2  NEA Producer Responsibility Scheme - ALBA E-wa...
# 3  NEA Producer Responsibility Scheme - ALBA E-wa...
# 4  NEA Producer Responsibility Scheme - ALBA E-wa...
#
#                                           descriptio LANDXADDRE PHOTOURL  \
# 0  Bin collection; E-waste accepted: ICT equipmen...       None     None
# 1  Bin collection; E-waste accepted: ICT equipmen...       None     None
# 2  Bin collection; E-waste accepted: ICT equipmen...       None     None
# 3  Bin collection; E-waste accepted: ICT equipmen...       None     None
# 4  Bin collection; E-waste accepted: ICT equipmen...       None     None
#
#   ADDRESSPOS LANDYADDRE                                          HYPERLINK  \
# 0     608549       None  https://alba-ewaste.sg; https://go.gov.sg/e-waste
# 1     608549       None  https://alba-ewaste.sg; https://go.gov.sg/e-waste
# 2     609601       None  https://alba-ewaste.sg; https://go.gov.sg/e-waste
# 3     609601       None  https://alba-ewaste.sg; https://go.gov.sg/e-waste
# 4     658713       None  https://alba-ewaste.sg; https://go.gov.sg/e-waste
#
#   ADDRESSUNI ADDRESSFLO                 ADDRESSBUI ADDRESSBLO  \
# 0       None       None               COURTS @ JEM       None
# 1       None       None            FAIRPRICE @ JEM       None
# 2       None       None                        IMM       None
# 3       None       None           CHALLENGER @ IMM       None
# 4       None       None  HARVEY NORMAN @ WEST MALL       None
#
#                                           ADDRESSSTR           INC_CRC  \
# 0                50 JURONG GATEWAY ROAD, JEM, #04-30  F0F20CDE76F503E4
# 1      50 JURONG GATEWAY RD, JEM, #B1-21/22 & #B3-01  F0F20CDEBD16F560
# 2                            2 JURONG EAST STREET 21  9FB1C7B3B9B927A4
# 3                2 JURONG EAST STREET 21, IMM, #2-23  9FB1C7B33B580E63
# 4  1 BUKIT BATOK CENTRAL LINK, WEST MALL, #03-06 ...  ABBDF39975274DEF
#
#        FMEL_UPD_D                                   geometry
# 0  20210920165422  POINT (103.743170436292 1.33320021038331)
# 1  20210920165422  POINT (103.743170436292 1.33320021038331)
# 2  20210920165422    POINT (103.7467344968 1.33489843717476)
# 3  20210920165422    POINT (103.7467344968 1.33489843717476)
# 4  20210920165422  POINT (103.749021980031 1.35018915982967)
